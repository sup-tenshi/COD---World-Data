# %%
#loading libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("adbc.csv")
df.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)  \
# 0                                            15925.0
# 1                                            16148.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8254 entries, 0 to 8253
# Data columns (total 36 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Entity                                                                                    8254 non-null   object
#  1   Code                                                                                      6206 non-null   object
#  2   Year                                                                                      8254 non-null   int64
#  3   Number of executions (Amnesty International)                                              267 non-null    object
#  4   Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                  8010 non-null   float64
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum() #showing the number of blank/null values in the data frame
# Out:
# Entity                                                                                         0
# Code                                                                                        2048
# Year                                                                                           0
# Number of executions (Amnesty International)                                                7987
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                     244
# Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)                                      244
# Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)                 244
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                        244
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                       244
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                         244
# ...

# %%
df1=df.drop('Code',axis='columns') # removing unwanted columns from the data frame
df1.isnull().sum()
# Out:
# Entity                                                                                         0
# Year                                                                                           0
# Number of executions (Amnesty International)                                                7987
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                     244
# Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)                                      244
# Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)                 244
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                        244
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                       244
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                         244
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)                                       244
# ...

# %%
# Here we are converting the year to an object and Execution in to float for easy calculation
df2=df1
df2=df2.fillna(0)
df2.head(20)
# Out:
#          Entity  Year Number of executions (Amnesty International)  \
# 0   Afghanistan  2007                                           15
# 1   Afghanistan  2008                                           17
# 2   Afghanistan  2009                                            0
# 3   Afghanistan  2011                                            2
# 4   Afghanistan  2012                                           14
# 5   Afghanistan  2013                                            2
# 6   Afghanistan  2014                                            6
# 7   Afghanistan  2015                                            1
# 8   Afghanistan  2016                                            6
# 9   Afghanistan  1990                                            0
# 10  Afghanistan  1991                                            0
# 11  Afghanistan  1992                                            0
# 12  Afghanistan  1993                                            0
# ...

# %%
df2.isnull().sum()
# Out:
# Entity                                                                                      0
# Year                                                                                        0
# Number of executions (Amnesty International)                                                0
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    0
# Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)                                     0
# Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)                0
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       0
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      0
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                        0
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)                                      0
# ...

# %%
# Here we are converting the year to an object and Execution in to float for easy calculation
df2['Year'] = df['Year'].apply(str)
df2['Number of executions (Amnesty International)'] = pd.to_numeric(df2['Number of executions (Amnesty International)'],errors = 'coerce')
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8254 entries, 0 to 8253
# Data columns (total 35 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Entity                                                                                    8254 non-null   object
#  1   Year                                                                                      8254 non-null   object
#  2   Number of executions (Amnesty International)                                              8237 non-null   float64
#  3   Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                  8254 non-null   float64
#  4   Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)                                   8254 non-null   float64
# ...

# %%
num_col = df2._get_numeric_data().columns.tolist() #identifying the numberic columns 
print(num_col)
# Out:
# ['Number of executions (Amnesty International)', 'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)', 'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)', 'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)', 'Deaths - Malaria - Sex: Both - Age: All Ages (Number)', 'Deaths - Drowning - Sex: Both - Age: All Ages (Number)', 'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)', 'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)', 'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)', 'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)', 'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)', 'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)', 'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)', 'Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)', 'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)', 'Deaths - Exposure to force
# ...

# %%
# here we are trying to find ther totla 
df2['Total_Deaths_Per_Year'] = df2.sum(axis = 1)
#df2.loc['Total_Deaths']= df2.sum(numeric_only=True, axis=0)
df2 = df2.replace(np.nan, '', regex=True)
df2.head()
# Out:
# C:\Users\abhis\AppData\Local\Temp/ipykernel_23164/739756805.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2['Total_Deaths_Per_Year'] = df2.sum(axis = 1)
#         Entity  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  2007                                         15.0
# 1  Afghanistan  2008                                         17.0
# 2  Afghanistan  2009                                          0.0
# 3  Afghanistan  2011                                          2.0
# 4  Afghanistan  2012                                         14.0
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# ...

# %%
# Here we are converting the year to an object and Execution in to float for easy calculation
df2['Year'] = df['Year'].apply(float)
df2['Number of executions (Amnesty International)'] = pd.to_numeric(df2['Number of executions (Amnesty International)'],errors = 'coerce')
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8254 entries, 0 to 8253
# Data columns (total 36 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Entity                                                                                    8254 non-null   object
#  1   Year                                                                                      8254 non-null   float64
#  2   Number of executions (Amnesty International)                                              8237 non-null   float64
#  3   Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                  8254 non-null   float64
#  4   Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)                                   8254 non-null   float64
# ...
